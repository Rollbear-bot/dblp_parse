# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# import xml
import xml.sax
# from xml.sax import make_parser

# import xml.etree.ElementTree as ET

# c语言实现版本
import xml.etree.cElementTree as ET

# %% [markdown]
# # 零、读入数据，并设置解析标签

# %%
# 全局变量
data_list = []

# %%
# # 解析器：需要设置标签名
# class MyContentHandler(xml.sax.ContentHandler):
#     def __init__(self):
#         super().__init__()
#         self.currentData = ""
#         # 声明的标签名
#         self.dblp = ""
#         self.phdthesis = ""
#         self.author = ""
#         self.title = ""
#         self.year = ""
#         self.school = ""
#         self.pages = ""
#         self.isbn = ""
#         self.ee = ""
        
#     def startDocument(self):
#         """文档头部回调"""
#         print("开始解析")
        
#     def endDocument(self):
#         """文档尾部回调"""
#         print("解析结束")
        
#     def startElement(self, name, attrs):
#         self.currentData = name
        
#     def endElement(self, name):
#         global data_list  # declar as global v
# #         if name == "name":
# #             data_list.append(self.name)
# #         elif name == "age":
# #             data_list.append(self.age)
# #         elif name == "gender":
# #             data_list.append(self.gender)
            
#         if name == "dblp":
#             data_list.append(self.dblp)
#         elif name == "phdthesis":
#             data_list.append(self.phdthesis)
#         elif name == "author":
#             data_list.append(self.author)
#         elif name == "title":
#             data_list.append(self.title)
#         elif name == "year":
#             data_list.append(self.year)
#         elif name == "school":
#             data_list.append(self.school)
#         elif name == "pages":
#             data_list.append(self.pages)
#         elif name == "isbn":
#             data_list.append(self.isbn)
#         elif name == "ee":
#             data_list.append(self.ee)
            
#     def characters(self, content):
# #         if self.currentData == "name":
# #             self.name = content
# #         elif self.currentData == "age":
# #             self.age = content
# #         elif self.currentData == "gender":
# #             self.gender = content
            
#         if self.currentData == "dblp":
#             self.dblp = content
#         elif self.currentData == "phdthesis":
#             self.phdthesis = content
#         elif self.currentData == "author":
#             self.author = content
#         elif self.currentData == "title":
#             self.title = content
#         elif self.currentData == "year":
#             self.year = content
#         elif self.currentData == "school":
#             self.school = content
#         elif self.currentData == "pages":
#             self.pages = content
#         elif self.currentData == "isbn":
#             self.isbn = content
#         elif self.currentData == "ee":
#             self.ee = content

# %%
# 待解析的xml文件的存储路径
xml_path = "/kaggle/input/dblp-raw/dblp-2020-09-01.xml"

tmp_path = "./tmp.xml"

# %%
with open(xml_path, "r", encoding="utf8") as rf:
    xml_str = rf.read()
    tmp = rf.readlines()[:12]
    with open(tmp_path, "w", encoding="utf8") as wf:
        wf.writelines(tmp)
        
# tmp

# %% [markdown]
# 标签名：
#
# 1. phdthesis
# 2. author
# 3. title
# 4. year
# 5. school
# 6. pages
# 7. isbn
# 8. ee

# %%
# 做一下截断处理
# xml_str = xml_str[:1000]

print(len(xml_str))

# %%
# with open(xml_path, "r", encoding="utf8") as rf:
#     tmp = rf.readlines()[:50]
    
# tmp

# %% [markdown]
# # 二、使用xml.sax解析器

# %%
# saxParse = xml.sax.make_parser()
# # 关闭命名解析
# saxParse.setFeature(xml.sax.handler.feature_namespaces, 0)
# handler =MyContentHandler()
# saxParse.setContentHandler(handler)

# # xml路径
# saxParse.parse(tmp_path)

# print(data_list)

# %%
# tree = ET.parse(xml_path)
# root = tree.getroot()

# %%
# tmp_str = "".join(tmp).split('<phdthesis mdate="2020-02-12" key')[0]

# tmp_str += "</dblp>"
# tmp_str

# %%
# 直接从字符串解析
root = ET.fromstring(xml_str)

# %%
for child in root:
    print(child.tag, child.attrib)
